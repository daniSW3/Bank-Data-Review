# %%
import oracledb

# %%
# Replace with your actual Oracle connection details
username = "sys"
password = "1234Dani@ethc#"
dsn = "AGPHOIT07.AGP.LOCAL:1521/xepdb1"

# Connect to the Oracle database as SYSDBA
connection = oracledb.connect(
    user=username,
    password=password,
    dsn=dsn,
    mode=oracledb.SYSDBA
)

cursor = connection.cursor()

# %%
# ... (rest of your database operations would go here)

# Remember to close when done
# cursor.close()
# connection.close()

# Query data from a table
cursor.execute('SELECT * FROM text_table')
print("Data from text_table:")

# Fetch all rows at once
rows = cursor.fetchall()
for row in rows:
    print(row)

# Get column information
columns = [col[0] for col in cursor.description]
print("Columns in text_table:", columns)
